# %%
import csv
data = {}
with open('Sahkonkulutus_kunnittain_2017.csv', newline='') as f:
    reader = csv.reader(f)
    for i, row in enumerate(reader):
        if i > 6:
            if not row[1]:
                break
            data[row[1]] = {
                'consumption_housing': int(row[2])+int(row[4]),
                'consumption_industry': int(row[3]),
                'consumption_total': int(row[5])
            }
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 import csv
#       2 data = {}
# ----> 3 with open('Sahkonkulutus_kunnittain_2017.csv', newline='') as f:
#       4     reader = csv.reader(f)
#       5     for i, row in enumerate(reader):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Sahkonkulutus_kunnittain_2017.csv'

# %%
from urllib.parse import urlencode, quote_plus
from requests import get
import json, time

not_found = []
url = 'https://geocode.maps.co/search?'
for name in data:
    params = urlencode({'q': name+', Finland'}, quote_via=quote_plus)
    res = get(url+params)
    j = json.loads(res.text)
    if len(j) and res.ok:
        data[name]['lat'] = j[0]['lat']
        data[name]['lon'] = j[0]['lon']
    else:
        not_found.append(name)
        print(name)
    time.sleep(1)
#for k, v in data.items():
#    print(k, v)

# %%
print(data)
# Out:
# {'Helsinki': {'consumption_housing': 4324, 'consumption_industry': 243, 'consumption_total': 4567, 'lat': '60.1674881', 'lon': '24.9427473'}, 'Tornio': {'consumption_housing': 191, 'consumption_industry': 2980, 'consumption_total': 3172, 'lat': '65.8457589', 'lon': '24.1464'}, 'Lappeenranta': {'consumption_housing': 560, 'consumption_industry': 2428, 'consumption_total': 2987, 'lat': '61.0583713', 'lon': '28.1862742'}, 'Oulu': {'consumption_housing': 1387, 'consumption_industry': 1477, 'consumption_total': 2863, 'lat': '65.0118734', 'lon': '25.4716809'}, 'Kouvola': {'consumption_housing': 719, 'consumption_industry': 2062, 'consumption_total': 2781, 'lat': '60.8701996', 'lon': '26.7018042'}, 'Jämsä': {'consumption_housing': 167, 'consumption_industry': 2594, 'consumption_total': 2761, 'lat': '61.8639814', 'lon': '25.1845044'}, 'Rauma': {'consumption_housing': 280, 'consumption_industry': 2327, 'consumption_total': 2606, 'lat': '61.1289148', 'lon': '21.5039401'}, 'Porvoo': {'consumption_housing': 371, 'consumption_industry': 1832, 'consumption_total': 2203, 'lat': '60.3953913', 'lon': '25.6604862'}, 'Espoo': {'consumption_housing': 2070, 'consumption_industry': 104, 'consumption_total': 2174, 'lat': '60.2047672', 'lon': '24.6568435'}, 'Vantaa': {'consumption_housing': 1676, 'consumption_industry': 254, 'consumption_total': 1930, 'lat': '60.3091871', 'lon': '25.0364526'}, 'Kokkola': {'consumption_housing': 366, 'consumption_industry': 1464, 'consumption_total': 1830, 'lat': '63.8391421', 'lon': '23.1336845'}, 'Tampere': {'consumption_housing': 1497, 'consumption_industry': 318, 'consumption_total': 1815, 'lat': '61.4980214', 'lon': '23.7603118'}, 'Imatra': {'consumption_housing': 204, 'consumption_industry': 1558, 'consumption_total': 1762, 'lat': '61.1923342', 'lon': '28.7716996'}, 'Joensuu': {'consumption_housing': 509, 'consumption_industry': 1115, 'consumption_total': 1623, 'lat': '62.6006257', 'lon': '29.7584591'}, 'Turku': {'consumption_housing': 1263, 'consumption_industry': 253, 'consumption_total': 1516, 'lat': '60.4517531', 'lon': '22.2670522'}, 'Kemi': {'consumption_housing': 162, 'consumption_industry': 1352, 'consumption_total': 1514, 'lat': '65.7333404', 'lon': '24.5666495'}, 'Lohja': {'consumption_housing': 374, 'consumption_industry': 930, 'consumption_total': 1305, 'lat': '60.2526036', 'lon': '24.0684575'}, 'Raahe': {'consumption_housing': 164, 'consumption_industry': 1107, 'consumption_total': 1271, 'lat': '64.6796865', 'lon': '24.4709175'}, 'Jyväskylä': {'consumption_housing': 961, 'consumption_industry': 222, 'consumption_total': 1182, 'lat': '62.2393002', 'lon': '25.745951'}, 'Kotka': {'consumption_housing': 387, 'consumption_industry': 794, 'consumption_total': 1181, 'lat': '60.4674228', 'lon': '26.9450844'}, 'Kuopio': {'consumption_housing': 854, 'consumption_industry': 272, 'consumption_total': 1125, 'lat': '62.8241424', 'lon': '27.594561484488977'}, 'Lahti': {'consumption_housing': 809, 'consumption_industry': 284, 'consumption_total': 1093, 'lat': '60.9826014', 'lon': '25.6613764'}, 'Pori': {'consumption_housing': 616, 'consumption_industry': 448, 'consumption_total': 1063, 'lat': '61.4865542', 'lon': '21.7968951'}, 'Sastamala': {'consumption_housing': 196, 'consumption_industry': 748, 'consumption_total': 944, 'lat': '61.45004805', 'lon': '22.841660867901894'}, 'Äänekoski': {'consumption_housing': 132, 'consumption_industry': 781, 'consumption_total': 912, 'lat': '62.702322300000006', 'lon': '25.821183132214983'}, 'Hämeenlinna': {'consumption_housing': 554, 'consumption_industry': 292, 'consumption_total': 846, 'lat': '60.9948584', 'lon': '24.46654'}, 'Varkaus': {'consumption_housing': 136, 'consumption_industry': 688, 'consumption_total': 824, 'lat': '62.3176377', 'lon': '27.8681227'}, 'Kajaani': {'consumption_housing': 291, 'consumption_industry': 472, 'consumption_total': 762, 'lat': '64.2240872', 'lon': '27.7334227'}, 'Seinäjoki': {'consumption_housing': 495, 'consumption_industry': 231, 'consumpti ...

# %%
import pandas as pd
pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 pd.DataFrame(data)
#
# NameError: name 'data' is not defined

# %%
with open('finland_municipality_power_consumption_2017.json', 'w') as f:
    f.write(json.dumps(data))

# %%
import osmnx
gdf_finland = osmnx.geometries_from_place('Helsinki', tags={'admin_level':'8'})
print(gdf_finland.loc['relation']['geometry'])
# Out:
# osmid
# 34914    POLYGON ((24.78280 60.09996, 24.83567 60.13041...
# 34920    POLYGON ((24.74624 60.32228, 24.74646 60.32345...
# 35159    POLYGON ((25.10221 60.33525, 25.11255 60.33549...
# 36097    POLYGON ((24.50435 60.25650, 24.50444 60.27409...
# Name: geometry, dtype: geometry

# %%
import json

with open('finland_municipality_power_consumption_2017.json') as f:
    power = json.loads(f.read())

# %%
power = pd.DataFrame(power).T

# %%
from shapely.geometry import Point
power['geo'] = power.apply(lambda e: Point(float(e.lon),float(e.lat)), axis=1)
# Out:
# /home/till/.local/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:128: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
import geopandas as gpd
import pyproj
crs_gps = pyproj.CRS.from_epsg('4326')  # Merkator
crs_web = pyproj.CRS.from_epsg('3857')  # Pseudo-Merkator
power = gpd.GeoDataFrame(power, geometry='geo', crs=crs_gps)

# %%
import contextily as ctx
ax=power.to_crs(crs_web).plot()
ctx.add_basemap(ax=ax, zoom=9)
